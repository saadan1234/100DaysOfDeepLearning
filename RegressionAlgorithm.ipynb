# %% [markdown]
# <a href="https://colab.research.google.com/github/saadan1234/100DaysOfDeepLearning/blob/main/RegressionAlgorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %% [markdown]
# # Initialization given ANN Dimenstions

# %%
def initialize_parameters(dim):
  np.random.seed(3)
  parameters = {}
  layers = len(dim)
  for l in range(1,layers):
    parameters['W' + str(l)] = np.ones((dim[l-1],dim[l]))*0.1
    parameters['b' + str(l)] = np.zeros((dim[l],1))
  return parameters

# %% [markdown]
# # Forward Propogation

# %%
def linear_activation(W, b, x_prev):
  print(f"\nActivation Function Running")
  z = np.dot(W.T,x_prev)+ b
  return z

# %%
def forward_propogation(X, parameters):
  A=X
  L = L = len(parameters) // 2
  #
  for l in range(1, L+1):
    print(f"\nForward Propogration Running for Layer{l}")
    #Last layer outputs become inputs
    x_prev = A
    wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    A = linear_activation(wl, bl, x_prev)
    print(f"w{l}: ", wl)
    print(f"b{l}: ", bl)
    print("A: ", A)
  return A,x_prev

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  print(f"\nParameters Updation")
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 1

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat,A1 = forward_propogation(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# Forward Propogration Running for Layer1
#
# Activation Function Running
# w1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# A:  [[1.6]
#  [1.6]]
#
# Forward Propogration Running for Layer2
#
# Activation Function Running
# w2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# A:  [[0.32]]
#
# Parameters Updation
#
# Forward Propogration Running for Layer1
#
# Activation Function Running
# w1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# A:  [[1.70612461]
#  [1.70612461]]
#
# Forward Propogration Running for Layer2
#
# Activation Function Running
# w2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.119136]]
# A:  [[0.50054357]]
#
# Parameters Updation
#
# Forward Propogration Running for Layer1
#
# Activation Function Running
# w1:  [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1:  [[0.0019667]
#  [0.0019667]]
# A:  [[1.83539945]
#  [1.87200826]]
#
# Forward Propogration Running for Layer2
#
# Activation Function Running
# w2:  [[0.12712927]
# ...
